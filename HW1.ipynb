# %% [markdown]
# # Mert Sasmaz 24290

# %% [markdown]
#  1) Use Pandas to read the iris dataset from
#
# url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
# !pip install pandas
import pandas as pd

db = pd.read_csv('iris.data')
#I couldnt locate the file but imported each time instead.

# %% [markdown]
#  2) Add column names  "SepalLength", "SepalWidth", "PetalLength", "PetalWidth", "Output"  to your data

# %%
db.columns = ["SepalLength", "SepalWidth", "PetalLength", "PetalWidth", "Output"]

# %% [markdown]
#  3) Print full dataset

# %%
db

# %% [markdown]
#  4) Print the shape of the dataset

# %%
db.shape
# Out:
# (149, 5)

# %% [markdown]
#  5) Print the column names

# %%
db.columns

# %% [markdown]
#  6) Print random 10, top 10 and last 10 records

# %%
top10 = db.head(10)
top10

# %%
last10 = db.tail(10)
last10

# %%
random10 = db.sample(10)
random10

# %% [markdown]
#  7) Print the 100th row

# %%
row100 = db.iloc[100:101]
row100
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth          Output
# 100          5.8         2.7          5.1         1.9  Iris-virginica
